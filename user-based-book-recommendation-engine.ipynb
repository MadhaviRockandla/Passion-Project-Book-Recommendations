# %%
# Importing Libraries
import pandas as pd

# %%
# Adjusting pandas dataframe settings
pd.set_option('display.max_columns', 500)

# %%
# Reading Dataframes
books = pd.read_csv("BRS-Dataset/Books.csv", low_memory='False')
ratings = pd.read_csv("BRS-Dataset/Book-Ratings.csv", low_memory='False')
users = pd.read_csv("BRS-Dataset/Users.csv", low_memory='False')
# Out:
# /var/folders/26/nhlrw59x2f1d6s6ljr___mm40000gp/T/ipykernel_34782/698788534.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("BRS-Dataset/Books.csv", low_memory='False')

# %%
# Merging Dataframes
temp_df = books.merge(ratings, how='left', on='ISBN')
final_df = temp_df.merge(users, how='left', on='User-ID')
final_df.shape
# Out:
# (1032345, 12)

# %%
# Creating user book matrix.
def user_book_df(dataframe):
    dataframe.drop(['Image-URL-S', 'Image-URL-M', 'Image-URL-L'], axis=1, inplace=True)
    dataframe.dropna(inplace=True)
    dataframe['User-ID'] = dataframe['User-ID'].astype('int')
    final_df = dataframe[dataframe["Book-Rating"] > 0]

    rating_book = pd.DataFrame(final_df['Book-Title'].value_counts())

    rare_books = rating_book[rating_book['Book-Title'] <= 85].index

    common_books = final_df[~final_df["Book-Title"].isin(rare_books)]
    user_book_matrix = common_books.pivot_table(index=['User-ID'], columns=['Book-Title'], values='Book-Rating')
    return user_book_matrix


user_book_matrix = user_book_df(final_df)

# %%
# Let's choose a user and recommend books to him/her.
# User Based Collaborative Filtering Engine provide us a recommendation system by using user similarities instead of item similarities.
# In that case, a score is calculated for users according to their ratings and correlations. This calculation can be weighted, that means,
# if you are thinking that the ratings are more important than readers correlations, you can give more weight to ratings. In this case, i will make it like this.
user = int('153662')

# %%
# Choosing user from user_book_matrix
user_df = user_book_matrix[user_book_matrix.index == user]
user_df
# Out:
# Book-Title  1984  1st to Die: A Novel  2nd Chance  A Bend in the Road  \
# User-ID
# 153662       NaN                  NaN         NaN                 NaN
#
# Book-Title  A Heartbreaking Work of Staggering Genius  A Painted House  \
# User-ID
# 153662                                            NaN              NaN
#
# Book-Title  A Prayer for Owen Meany  A Time to Kill  A Walk to Remember  \
# User-ID
# 153662                          NaN            10.0                 NaN
#
# Book-Title  ANGELA'S ASHES  American Gods  Angels &amp; Demons  Animal Farm  \
# User-ID
# 153662                 NaN            NaN                  NaN          NaN
#
# Book-Title  Balzac and the Little Chinese Seamstress : A Novel  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  Bel Canto: A Novel  Brave New World  Bridget Jones's Diary  \
# User-ID
# 153662                     NaN              NaN                    9.0
#
# Book-Title  Chocolat  \
# User-ID
# 153662           NaN
#
# Book-Title  Confessions of a Shopaholic (Summer Display Opportunity)  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  Digital Fortress : A Thriller  \
# User-ID
# 153662                                NaN
#
# Book-Title  Divine Secrets of the Ya-Ya Sisterhood: A Novel  \
# User-ID
# 153662                                                  NaN
#
# Book-Title  Dolores Claiborne  Dreamcatcher  Empire Falls  \
# User-ID
# 153662                    NaN           NaN           NaN
#
# Book-Title  Ender's Game (Ender Wiggins Saga (Paperback))  Fahrenheit 451  \
# User-ID
# 153662                                                NaN            10.0
#
# Book-Title  Fast Food Nation: The Dark Side of the All-American Meal  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  Girl with a Pearl Earring  Girl, Interrupted  Good in Bed  \
# User-ID
# 153662                            NaN                NaN          NaN
#
# Book-Title  Hannibal  \
# User-ID
# 153662           NaN
#
# Book-Title  Hard Eight : A Stephanie Plum Novel (A Stephanie Plum Novel)  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  Harry Potter and the Chamber of Secrets (Book 2)  \
# User-ID
# 153662                                                  10.0
#
# Book-Title  Harry Potter and the Goblet of Fire (Book 4)  \
# User-ID
# 153662                                              10.0
#
# Book-Title  Harry Potter and the Order of the Phoenix (Book 5)  \
# User-ID
# 153662                                                   10.0
#
# Book-Title  Harry Potter and the Prisoner of Azkaban (Book 3)  \
# User-ID
# 153662                                                   10.0
#
# Book-Title  Harry Potter and the Sorcerer's Stone (Book 1)  \
# User-ID
# 153662                                                 NaN
#
# Book-Title  Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))  \
# User-ID
# 153662                                                   10.0
#
# Book-Title  High Fidelity  House of Sand and Fog  How to Be Good  Icy Sparks  \
# User-ID
# 153662                NaN                    5.0             NaN         NaN
#
# Book-Title  Interview with the Vampire  \
# User-ID
# 153662                             NaN
#
# Book-Title  Into Thin Air : A Personal Account of the Mt. Everest Disaster  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  Jurassic Park  \
# User-ID
# 153662                NaN
#
# Book-Title  Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)  \
# User-ID
# 153662                                                    9.0
#
# Book-Title  Life of Pi  Little Altars Everywhere: A Novel  Lord of the Flies  \
# User-ID
# 153662             NaN                                NaN                NaN
#
# Book-Title  Lucky : A Memoir  Me Talk Pretty One Day  Message in a Bottle  \
# User-ID
# 153662                   NaN                     NaN                  NaN
#
# Book-Title  Midwives: A Novel  Misery  Mystic River  Neverwhere  \
# User-ID
# 153662                    9.0     NaN           NaN         NaN
#
# Book-Title  Nickel and Dimed: On (Not) Getting By in America  \
# User-ID
# 153662                                                   NaN
#
# Book-Title  One Door Away from Heaven  Outlander  Red Dragon  SHIPPING NEWS  \
# User-ID
# 153662                            NaN        NaN         NaN            NaN
#
# Book-Title  She's Come Undone (Oprah's Book Club (Paperback))  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  She's Come Undone (Oprah's Book Club)  Silence of the Lambs  \
# User-ID
# 153662                                        NaN                   NaN
#
# Book-Title  Skipping Christmas  Snow Falling on Cedars  Sphere  \
# User-ID
# 153662                     NaN                    10.0     NaN
#
# Book-Title  Stupid White Men ...and Other Sorry Excuses for the State of the Nation!  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  Summer Sisters  Suzanne's Diary for Nicholas  The Alienist  \
# User-ID
# 153662                 NaN                           NaN          10.0
#
# Book-Title  The Bad Beginning (A Series of Unfortunate Events, Book 1)  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  The Beach House  The Bean Trees  The Bonesetter's Daughter  \
# User-ID
# 153662                  NaN             NaN                        NaN
#
# Book-Title  The Brethren  The Bridges of Madison County  \
# User-ID
# 153662               5.0                            NaN
#
# Book-Title  The Catcher in the Rye  The Chamber  The Cider House Rules  \
# User-ID
# 153662                         NaN          NaN                    NaN
#
# Book-Title  The Client  The Color Purple  The Da Vinci Code  \
# User-ID
# 153662            10.0               NaN                NaN
#
# Book-Title  The Divine Secrets of the Ya-Ya Sisterhood: A Novel  \
# User-ID
# 153662                                                   10.0
#
# Book-Title  The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# User-ID
# 153662                                                   10.0
#
# Book-Title  The Firm  The Five People You Meet in Heaven  \
# User-ID
# 153662           NaN                                 NaN
#
# Book-Title  The Girls' Guide to Hunting and Fishing  \
# User-ID
# 153662                                          NaN
#
# Book-Title  The Golden Compass (His Dark Materials, Book 1)  The Great Gatsby  \
# User-ID
# 153662                                                  NaN               NaN
#
# Book-Title  The Handmaid's Tale  The Hitchhiker's Guide to the Galaxy  \
# User-ID
# 153662                      NaN                                  10.0
#
# Book-Title  The Hobbit : The Enchanting Prelude to The Lord of the Rings  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  The Horse Whisperer  The Joy Luck Club  The King of Torts  \
# User-ID
# 153662                      NaN                9.0                NaN
#
# Book-Title  The Last Time They Met : A Novel  The Lovely Bones: A Novel  \
# User-ID
# 153662                                   NaN                        NaN
#
# Book-Title  The Nanny Diaries: A Novel  \
# User-ID
# 153662                             NaN
#
# Book-Title  The No. 1 Ladies' Detective Agency (Today Show Book Club #8)  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  The Notebook  The Partner  The Pelican Brief  \
# User-ID
# 153662               NaN          NaN                9.0
#
# Book-Title  The Pilot's Wife : A Novel  The Poisonwood Bible: A Novel  \
# User-ID
# 153662                             NaN                            NaN
#
# Book-Title  The Rainmaker  The Reader  The Red Tent (Bestselling Backlist)  \
# User-ID
# 153662                NaN         NaN                                  NaN
#
# Book-Title  The Rescue  The Runaway Jury  The Secret Life of Bees  \
# User-ID
# 153662             NaN               NaN                      NaN
#
# Book-Title  The Street Lawyer  The Subtle Knife (His Dark Materials, Book 2)  \
# User-ID
# 153662                    NaN                                            NaN
#
# Book-Title  The Summons  The Testament  \
# User-ID
# 153662              NaN            9.0
#
# Book-Title  The Two Towers (The Lord of the Rings, Part 2)  \
# User-ID
# 153662                                                 NaN
#
# Book-Title  The Vampire Lestat (Vampire Chronicles, Book II)  Timeline  \
# User-ID
# 153662                                                   NaN       NaN
#
# Book-Title  To Kill a Mockingbird  \
# User-ID
# 153662                        NaN
#
# Book-Title  Tuesdays with Morrie: An Old Man, a Young Man, and Life's Greatest Lesson  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  Watership Down  We Were the Mulvaneys  When the Wind Blows  \
# User-ID
# 153662                 NaN                    NaN                 10.0
#
# Book-Title  Where the Heart Is (Oprah's Book Club (Paperback))  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  While I Was Gone  White Oleander : A Novel  \
# User-ID
# 153662                   NaN                       NaN
#
# Book-Title  White Oleander : A Novel (Oprah's Book Club)  \
# User-ID
# 153662                                               9.0
#
# Book-Title  Wicked: The Life and Times of the Wicked Witch of the West  \
# User-ID
# 153662                                                    NaN
#
# Book-Title  Wild Animus
# User-ID
# 153662              NaN

# %%
# Taking read books by user.
user_read_books = user_df.columns[user_df.notna().any()].tolist()
user_read_books
# Out:
# ['A Time to Kill',
#  "Bridget Jones's Diary",
#  'Fahrenheit 451',
#  'Harry Potter and the Chamber of Secrets (Book 2)',
#  'Harry Potter and the Goblet of Fire (Book 4)',
#  'Harry Potter and the Order of the Phoenix (Book 5)',
#  'Harry Potter and the Prisoner of Azkaban (Book 3)',
#  "Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#  'House of Sand and Fog',
#  "Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)",
#  'Midwives: A Novel',
#  'Snow Falling on Cedars',
#  'The Alienist',
#  'The Brethren',
#  'The Client',
#  'The Divine Secrets of the Ya-Ya Sisterhood: A Novel',
#  'The Fellowship of the Ring (The Lord of the Rings, Part 1)',
#  "The Hitchhiker's Guide to the Galaxy",
#  'The Joy Luck Club',
#  'The Pelican Brief',
#  'The Testament',
#  'When the Wind Blows',
#  "White Oleander : A Novel (Oprah's Book Club)"]

# %%
# How many books are read by user?
len(user_read_books) # 23
# Out:
# 23

# %%
# Choosing users book with all users.
read_books = user_book_matrix[user_read_books]
read_books.head()
# Out:
# Book-Title  A Time to Kill  Bridget Jones's Diary  Fahrenheit 451  \
# User-ID
# 51                     NaN                    NaN             NaN
# 114                    NaN                    NaN             NaN
# 165                    NaN                    NaN             NaN
# 183                    NaN                    NaN             9.0
# 242                    NaN                    NaN             8.0
#
# Book-Title  Harry Potter and the Chamber of Secrets (Book 2)  \
# User-ID
# 51                                                       NaN
# 114                                                      NaN
# 165                                                      NaN
# 183                                                      NaN
# 242                                                      NaN
#
# Book-Title  Harry Potter and the Goblet of Fire (Book 4)  \
# User-ID
# 51                                                   NaN
# 114                                                  NaN
# 165                                                  NaN
# 183                                                  NaN
# 242                                                  NaN
#
# Book-Title  Harry Potter and the Order of the Phoenix (Book 5)  \
# User-ID
# 51                                                        NaN
# 114                                                       NaN
# 165                                                       NaN
# 183                                                       NaN
# 242                                                       NaN
#
# Book-Title  Harry Potter and the Prisoner of Azkaban (Book 3)  \
# User-ID
# 51                                                        NaN
# 114                                                       NaN
# 165                                                       NaN
# 183                                                       NaN
# 242                                                       NaN
#
# Book-Title  Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))  \
# User-ID
# 51                                                        NaN
# 114                                                       NaN
# 165                                                       NaN
# 183                                                       NaN
# 242                                                       NaN
#
# Book-Title  House of Sand and Fog  \
# User-ID
# 51                            NaN
# 114                           NaN
# 165                           NaN
# 183                           NaN
# 242                           NaN
#
# Book-Title  Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)  \
# User-ID
# 51                                                        NaN
# 114                                                       NaN
# 165                                                       NaN
# 183                                                       NaN
# 242                                                       NaN
#
# Book-Title  Midwives: A Novel  Snow Falling on Cedars  The Alienist  \
# User-ID
# 51                        NaN                     NaN           NaN
# 114                       NaN                     NaN           NaN
# 165                       NaN                     NaN           NaN
# 183                       NaN                     NaN           NaN
# 242                       NaN                     NaN           NaN
#
# Book-Title  The Brethren  The Client  \
# User-ID
# 51                   NaN         NaN
# 114                  NaN         NaN
# 165                  NaN         NaN
# 183                  NaN         NaN
# 242                  NaN         NaN
#
# Book-Title  The Divine Secrets of the Ya-Ya Sisterhood: A Novel  \
# User-ID
# 51                                                        NaN
# 114                                                       NaN
# 165                                                       NaN
# 183                                                       NaN
# 242                                                       NaN
#
# Book-Title  The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# User-ID
# 51                                                        NaN
# 114                                                       NaN
# 165                                                       NaN
# 183                                                       NaN
# 242                                                       NaN
#
# Book-Title  The Hitchhiker's Guide to the Galaxy  The Joy Luck Club  \
# User-ID
# 51                                           NaN                NaN
# 114                                          NaN                NaN
# 165                                          NaN                NaN
# 183                                          NaN                NaN
# 242                                          NaN                NaN
#
# Book-Title  The Pelican Brief  The Testament  When the Wind Blows  \
# User-ID
# 51                        NaN            NaN                  NaN
# 114                       NaN            NaN                  NaN
# 165                       NaN            NaN                  NaN
# 183                       NaN            NaN                  NaN
# 242                       NaN            NaN                  NaN
#
# Book-Title  White Oleander : A Novel (Oprah's Book Club)
# User-ID
# 51                                                   NaN
# 114                                                  NaN
# 165                                                  NaN
# 183                                                  NaN
# 242                                                  NaN

# %%
user_book_count_df = read_books.T.notnull().sum().reset_index()
user_book_count_df.columns = ['User-ID','Count']
user_book_count_df['Count'].describe(percentiles=(0.1,0.25,0.4,0.6,0.75,0.9))
# Out:
# count    8742.000000
# mean        0.392473
# std         0.884887
# min         0.000000
# 10%         0.000000
# 25%         0.000000
# 40%         0.000000
# 50%         0.000000
# 60%         0.000000
# 75%         1.000000
# 90%         1.000000
# max        23.000000
# Name: Count, dtype: float64

# %%
user_book_count_df[user_book_count_df['Count'] > 5].shape
# Out:
# (32, 2)

# %%
# Choosing same readers with user
same_readers_with_user = user_book_count_df[user_book_count_df['Count'] > 5]['User-ID']
same_readers_with_user
# Out:
# 205       6563
# 514      16795
# 657      21576
# 693      22625
# 721      23872
# 935      30711
# 1119     36003
# 1750     55492
# 1910     60244
# 2117     66942
# 2711     85993
# 2999     95359
# 3204    101851
# 3230    102647
# 3232    102702
# 3339    105517
# 3614    114368
# 3993    125519
# 4386    136491
# 4415    137589
# 4908    153662
# 5066    159506
# 5254    165308
# 5695    179734
# 5846    185176
# 6546    208815
# 6887    220688
# 7188    229741
# 7464    238889
# 7531    240567
# 7575    242083
# 7794    248477
# Name: User-ID, dtype: int64

# %%
rec_df = pd.concat([read_books[read_books.index.isin(same_readers_with_user)],user_df[user_read_books]])
rec_df
# Out:
# Book-Title  A Time to Kill  Bridget Jones's Diary  Fahrenheit 451  \
# User-ID
# 6563                  10.0                    NaN             NaN
# 16795                  NaN                    7.0             8.0
# 21576                  NaN                    NaN             8.0
# 22625                  NaN                    NaN             NaN
# 23872                  9.0                    NaN             9.0
# 30711                  NaN                    6.0             NaN
# 36003                  NaN                   10.0             NaN
# 55492                  NaN                    NaN             NaN
# 60244                  NaN                    8.0             9.0
# 66942                  NaN                    NaN             NaN
# 85993                  NaN                    5.0             NaN
# 95359                  NaN                    NaN             NaN
# 101851                 9.0                    NaN             NaN
# 102647                10.0                    NaN             NaN
# 102702                 NaN                    NaN             NaN
# 105517                 NaN                    NaN             NaN
# 114368                10.0                    NaN             NaN
# 125519                10.0                   10.0             NaN
# 136491                10.0                    NaN             NaN
# 137589                 NaN                    NaN             8.0
# 153662                10.0                    9.0            10.0
# 159506                 NaN                    NaN             5.0
# 165308                 NaN                   10.0             NaN
# 179734                 NaN                   10.0             NaN
# 185176                 NaN                    NaN             NaN
# 208815                 NaN                    NaN             NaN
# 220688                 NaN                    9.0             NaN
# 229741                 NaN                    7.0             NaN
# 238889                 NaN                    1.0             NaN
# 240567                 NaN                    NaN             NaN
# 242083                10.0                    NaN             NaN
# 248477                 NaN                    9.0             NaN
# 153662                10.0                    9.0            10.0
#
# Book-Title  Harry Potter and the Chamber of Secrets (Book 2)  \
# User-ID
# 6563                                                     NaN
# 16795                                                    NaN
# 21576                                                    NaN
# 22625                                                   10.0
# 23872                                                   10.0
# 30711                                                    7.0
# 36003                                                   10.0
# 55492                                                   10.0
# 60244                                                    NaN
# 66942                                                    9.0
# 85993                                                   10.0
# 95359                                                    NaN
# 101851                                                  10.0
# 102647                                                   7.0
# 102702                                                  10.0
# 105517                                                   8.0
# 114368                                                   5.0
# 125519                                                   NaN
# 136491                                                   8.0
# 137589                                                   8.0
# 153662                                                  10.0
# 159506                                                   8.0
# 165308                                                  10.0
# 179734                                                   5.0
# 185176                                                   9.0
# 208815                                                  10.0
# 220688                                                  10.0
# 229741                                                   7.0
# 238889                                                  10.0
# 240567                                                   NaN
# 242083                                                   9.0
# 248477                                                   9.0
# 153662                                                  10.0
#
# Book-Title  Harry Potter and the Goblet of Fire (Book 4)  \
# User-ID
# 6563                                                 9.0
# 16795                                                NaN
# 21576                                                9.0
# 22625                                                NaN
# 23872                                               10.0
# 30711                                                NaN
# 36003                                               10.0
# 55492                                               10.0
# 60244                                                NaN
# 66942                                                9.0
# 85993                                               10.0
# 95359                                                NaN
# 101851                                              10.0
# 102647                                               NaN
# 102702                                              10.0
# 105517                                               6.0
# 114368                                               NaN
# 125519                                               NaN
# 136491                                               8.0
# 137589                                               8.0
# 153662                                              10.0
# 159506                                               9.0
# 165308                                              10.0
# 179734                                              10.0
# 185176                                               9.0
# 208815                                              10.0
# 220688                                              10.0
# 229741                                               7.0
# 238889                                              10.0
# 240567                                               NaN
# 242083                                               9.0
# 248477                                               9.0
# 153662                                              10.0
#
# Book-Title  Harry Potter and the Order of the Phoenix (Book 5)  \
# User-ID
# 6563                                                     10.0
# 16795                                                     NaN
# 21576                                                     9.0
# 22625                                                    10.0
# 23872                                                     NaN
# 30711                                                     8.0
# 36003                                                    10.0
# 55492                                                     9.0
# 60244                                                     NaN
# 66942                                                     7.0
# 85993                                                    10.0
# 95359                                                    10.0
# 101851                                                   10.0
# 102647                                                    9.0
# 102702                                                    NaN
# 105517                                                    4.0
# 114368                                                    NaN
# 125519                                                    NaN
# 136491                                                    9.0
# 137589                                                    NaN
# 153662                                                   10.0
# 159506                                                    8.0
# 165308                                                    NaN
# 179734                                                   10.0
# 185176                                                   10.0
# 208815                                                   10.0
# 220688                                                   10.0
# 229741                                                    8.0
# 238889                                                    NaN
# 240567                                                    NaN
# 242083                                                    7.0
# 248477                                                    9.0
# 153662                                                   10.0
#
# Book-Title  Harry Potter and the Prisoner of Azkaban (Book 3)  \
# User-ID
# 6563                                                      NaN
# 16795                                                     NaN
# 21576                                                     8.0
# 22625                                                     NaN
# 23872                                                    10.0
# 30711                                                     NaN
# 36003                                                    10.0
# 55492                                                    10.0
# 60244                                                     NaN
# 66942                                                     9.0
# 85993                                                    10.0
# 95359                                                     NaN
# 101851                                                   10.0
# 102647                                                    7.0
# 102702                                                   10.0
# 105517                                                    NaN
# 114368                                                    NaN
# 125519                                                    NaN
# 136491                                                    9.0
# 137589                                                    NaN
# 153662                                                   10.0
# 159506                                                    NaN
# 165308                                                    NaN
# 179734                                                   10.0
# 185176                                                   10.0
# 208815                                                   10.0
# 220688                                                   10.0
# 229741                                                    8.0
# 238889                                                   10.0
# 240567                                                    NaN
# 242083                                                    8.0
# 248477                                                    9.0
# 153662                                                   10.0
#
# Book-Title  Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))  \
# User-ID
# 6563                                                      8.0
# 16795                                                     NaN
# 21576                                                     NaN
# 22625                                                    10.0
# 23872                                                     NaN
# 30711                                                     NaN
# 36003                                                     NaN
# 55492                                                    10.0
# 60244                                                     NaN
# 66942                                                     9.0
# 85993                                                    10.0
# 95359                                                     NaN
# 101851                                                   10.0
# 102647                                                    NaN
# 102702                                                   10.0
# 105517                                                    NaN
# 114368                                                    NaN
# 125519                                                    NaN
# 136491                                                    NaN
# 137589                                                    NaN
# 153662                                                   10.0
# 159506                                                    7.0
# 165308                                                    NaN
# 179734                                                    NaN
# 185176                                                    NaN
# 208815                                                   10.0
# 220688                                                   10.0
# 229741                                                    NaN
# 238889                                                   10.0
# 240567                                                    NaN
# 242083                                                   10.0
# 248477                                                    NaN
# 153662                                                   10.0
#
# Book-Title  House of Sand and Fog  \
# User-ID
# 6563                          NaN
# 16795                         9.0
# 21576                         8.0
# 22625                         9.0
# 23872                         NaN
# 30711                         NaN
# 36003                         NaN
# 55492                         NaN
# 60244                         7.0
# 66942                         NaN
# 85993                         NaN
# 95359                         7.0
# 101851                        NaN
# 102647                        NaN
# 102702                        NaN
# 105517                        NaN
# 114368                        NaN
# 125519                       10.0
# 136491                        NaN
# 137589                        NaN
# 153662                        5.0
# 159506                        NaN
# 165308                        8.0
# 179734                        NaN
# 185176                        NaN
# 208815                        NaN
# 220688                        NaN
# 229741                        NaN
# 238889                        NaN
# 240567                        8.0
# 242083                        NaN
# 248477                        NaN
# 153662                        5.0
#
# Book-Title  Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)  \
# User-ID
# 6563                                                      NaN
# 16795                                                     9.0
# 21576                                                     NaN
# 22625                                                     NaN
# 23872                                                     NaN
# 30711                                                     NaN
# 36003                                                     NaN
# 55492                                                     NaN
# 60244                                                     5.0
# 66942                                                     NaN
# 85993                                                     NaN
# 95359                                                     NaN
# 101851                                                    NaN
# 102647                                                    NaN
# 102702                                                    NaN
# 105517                                                    NaN
# 114368                                                    NaN
# 125519                                                    NaN
# 136491                                                    NaN
# 137589                                                    NaN
# 153662                                                    9.0
# 159506                                                    NaN
# 165308                                                    NaN
# 179734                                                    NaN
# 185176                                                    NaN
# 208815                                                   10.0
# 220688                                                    NaN
# 229741                                                    NaN
# 238889                                                    NaN
# 240567                                                    NaN
# 242083                                                    NaN
# 248477                                                    NaN
# 153662                                                    9.0
#
# Book-Title  Midwives: A Novel  Snow Falling on Cedars  The Alienist  \
# User-ID
# 6563                      NaN                     NaN           NaN
# 16795                     7.0                     NaN           NaN
# 21576                     NaN                     NaN           NaN
# 22625                    10.0                    10.0           NaN
# 23872                     NaN                     NaN           NaN
# 30711                     NaN                     NaN           NaN
# 36003                     NaN                     8.0           NaN
# 55492                     NaN                     NaN           NaN
# 60244                     NaN                     NaN           NaN
# 66942                     NaN                     NaN           NaN
# 85993                     NaN                     NaN           NaN
# 95359                     NaN                     NaN           9.0
# 101851                    NaN                     NaN           NaN
# 102647                    NaN                     NaN           NaN
# 102702                    NaN                     NaN           NaN
# 105517                    NaN                     NaN           4.0
# 114368                    NaN                     NaN           NaN
# 125519                    NaN                     NaN           NaN
# 136491                    NaN                     NaN           NaN
# 137589                    8.0                     8.0           NaN
# 153662                    9.0                    10.0          10.0
# 159506                    NaN                     NaN           NaN
# 165308                    7.0                     NaN           NaN
# 179734                    NaN                     NaN           NaN
# 185176                    NaN                     NaN           NaN
# 208815                    NaN                     NaN           NaN
# 220688                    NaN                     NaN           NaN
# 229741                    NaN                     NaN           NaN
# 238889                    NaN                     NaN           5.0
# 240567                    NaN                     NaN           7.0
# 242083                    NaN                     4.0           NaN
# 248477                    NaN                     NaN           NaN
# 153662                    9.0                    10.0          10.0
#
# Book-Title  The Brethren  The Client  \
# User-ID
# 6563                 NaN         9.0
# 16795                NaN         5.0
# 21576                NaN         NaN
# 22625                NaN         NaN
# 23872                NaN         NaN
# 30711                NaN         NaN
# 36003                NaN         NaN
# 55492                NaN         NaN
# 60244                NaN         NaN
# 66942                NaN         NaN
# 85993                7.0         NaN
# 95359                7.0         NaN
# 101851               NaN         8.0
# 102647               NaN         8.0
# 102702               NaN         NaN
# 105517               NaN         NaN
# 114368               6.0        10.0
# 125519               NaN        10.0
# 136491               NaN         NaN
# 137589               7.5         7.0
# 153662               5.0        10.0
# 159506               NaN         8.0
# 165308               NaN         NaN
# 179734               NaN         NaN
# 185176               NaN         8.0
# 208815               NaN         NaN
# 220688               NaN         NaN
# 229741               NaN         NaN
# 238889               NaN         8.0
# 240567               6.0         8.0
# 242083               5.0         NaN
# 248477               NaN         NaN
# 153662               5.0        10.0
#
# Book-Title  The Divine Secrets of the Ya-Ya Sisterhood: A Novel  \
# User-ID
# 6563                                                      NaN
# 16795                                                     NaN
# 21576                                                     8.0
# 22625                                                     NaN
# 23872                                                     NaN
# 30711                                                     8.0
# 36003                                                     NaN
# 55492                                                     5.0
# 60244                                                     8.0
# 66942                                                     NaN
# 85993                                                     NaN
# 95359                                                     NaN
# 101851                                                    NaN
# 102647                                                    NaN
# 102702                                                    NaN
# 105517                                                    NaN
# 114368                                                    NaN
# 125519                                                    NaN
# 136491                                                    NaN
# 137589                                                    8.0
# 153662                                                   10.0
# 159506                                                    NaN
# 165308                                                    NaN
# 179734                                                    NaN
# 185176                                                    NaN
# 208815                                                    NaN
# 220688                                                    NaN
# 229741                                                    NaN
# 238889                                                    NaN
# 240567                                                    NaN
# 242083                                                    NaN
# 248477                                                    NaN
# 153662                                                   10.0
#
# Book-Title  The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# User-ID
# 6563                                                      NaN
# 16795                                                     8.0
# 21576                                                     NaN
# 22625                                                     NaN
# 23872                                                    10.0
# 30711                                                     9.0
# 36003                                                     NaN
# 55492                                                     NaN
# 60244                                                    10.0
# 66942                                                     NaN
# 85993                                                     NaN
# 95359                                                     NaN
# 101851                                                    NaN
# 102647                                                    NaN
# 102702                                                   10.0
# 105517                                                    NaN
# 114368                                                    NaN
# 125519                                                    NaN
# 136491                                                    9.0
# 137589                                                    NaN
# 153662                                                   10.0
# 159506                                                   10.0
# 165308                                                    NaN
# 179734                                                    5.0
# 185176                                                    9.0
# 208815                                                    NaN
# 220688                                                    NaN
# 229741                                                    NaN
# 238889                                                    NaN
# 240567                                                    NaN
# 242083                                                    6.0
# 248477                                                    NaN
# 153662                                                   10.0
#
# Book-Title  The Hitchhiker's Guide to the Galaxy  The Joy Luck Club  \
# User-ID
# 6563                                         NaN                NaN
# 16795                                        NaN                NaN
# 21576                                        NaN                NaN
# 22625                                        NaN                NaN
# 23872                                       10.0                NaN
# 30711                                        7.0                NaN
# 36003                                        NaN                NaN
# 55492                                        NaN                NaN
# 60244                                        9.0                8.0
# 66942                                        NaN               10.0
# 85993                                        NaN                NaN
# 95359                                       10.0                NaN
# 101851                                       NaN               10.0
# 102647                                       NaN                NaN
# 102702                                       NaN                NaN
# 105517                                       6.0                NaN
# 114368                                       NaN                NaN
# 125519                                       NaN                NaN
# 136491                                       NaN                NaN
# 137589                                       NaN                8.0
# 153662                                      10.0                9.0
# 159506                                       NaN                NaN
# 165308                                       NaN                NaN
# 179734                                       NaN                NaN
# 185176                                       NaN                NaN
# 208815                                       NaN                NaN
# 220688                                       NaN                NaN
# 229741                                       NaN                NaN
# 238889                                       NaN                NaN
# 240567                                       NaN                8.0
# 242083                                       2.0                NaN
# 248477                                       7.0                NaN
# 153662                                      10.0                9.0
#
# Book-Title  The Pelican Brief  The Testament  When the Wind Blows  \
# User-ID
# 6563                      NaN            NaN                  5.0
# 16795                     6.0            NaN                  8.0
# 21576                     NaN            NaN                  NaN
# 22625                     NaN            NaN                  NaN
# 23872                     NaN           10.0                  NaN
# 30711                     NaN            NaN                  NaN
# 36003                     NaN            NaN                  NaN
# 55492                     NaN            NaN                  NaN
# 60244                     NaN            NaN                  NaN
# 66942                     NaN            NaN                  NaN
# 85993                     NaN            NaN                  NaN
# 95359                     NaN            NaN                  3.0
# 101851                    NaN            NaN                  NaN
# 102647                    8.0            NaN                  9.0
# 102702                    8.0            NaN                  NaN
# 105517                    5.0            NaN                  NaN
# 114368                   10.0            8.0                  NaN
# 125519                   10.0            8.0                  9.0
# 136491                    NaN            NaN                  NaN
# 137589                    7.0            8.0                  NaN
# 153662                    9.0            9.0                 10.0
# 159506                    NaN            8.0                  NaN
# 165308                    NaN            NaN                  NaN
# 179734                    NaN            NaN                  NaN
# 185176                    NaN            NaN                  NaN
# 208815                    NaN            NaN                  NaN
# 220688                    NaN            NaN                  NaN
# 229741                    7.0            NaN                  NaN
# 238889                    NaN            NaN                  NaN
# 240567                    5.0            5.0                  7.0
# 242083                    9.0            NaN                  NaN
# 248477                    NaN            NaN                  NaN
# 153662                    9.0            9.0                 10.0
#
# Book-Title  White Oleander : A Novel (Oprah's Book Club)
# User-ID
# 6563                                                 NaN
# 16795                                                NaN
# 21576                                                NaN
# 22625                                                NaN
# 23872                                                NaN
# 30711                                                NaN
# 36003                                                NaN
# 55492                                                NaN
# 60244                                                8.0
# 66942                                                NaN
# 85993                                                NaN
# 95359                                                6.0
# 101851                                               NaN
# 102647                                               NaN
# 102702                                               NaN
# 105517                                               7.0
# 114368                                               NaN
# 125519                                               NaN
# 136491                                               NaN
# 137589                                               NaN
# 153662                                               9.0
# 159506                                               NaN
# 165308                                               8.0
# 179734                                               NaN
# 185176                                               NaN
# 208815                                               NaN
# 220688                                               NaN
# 229741                                               NaN
# 238889                                               NaN
# 240567                                               NaN
# 242083                                               NaN
# 248477                                               NaN
# 153662                                               9.0

# %%
# We should take correlations between users, that's why users that in the rec_df have to change from index to columns.
correlation_df = rec_df.T.corr().unstack().sort_values(ascending=False).drop_duplicates()
correlation_df = pd.DataFrame(correlation_df,columns=['correlation'])
correlation_df.index.names = ['User-ID-1','User-ID-2']
correlation_df = correlation_df.reset_index()
correlation_df.head(10)
# Out:
#    User-ID-1  User-ID-2  correlation
# 0      55492      66942     1.000000
# 1     153662     102702     1.000000
# 2     238889     220688     1.000000
# 3     105517     105517     1.000000
# 4     137589      85993     1.000000
# 5     137589     185176     1.000000
# 6       6563     125519     0.981981
# 7     153662      22625     0.979796
# 8      21576     159506     0.970725
# 9     242083     248477     0.958706

# %%
# We can choose users with more than 0.70 correlation with selected user.
similar_users = correlation_df[(correlation_df['correlation'] >= 0.70) & (correlation_df['User-ID-1'] == user)][['User-ID-2','correlation']]
similar_users = similar_users.reset_index(drop=True)
similar_users.rename(columns={'User-ID-2':'User-ID',
                              'correlation':'Correlations'}, inplace=True)
similar_users
# Out:
#    User-ID  Correlations
# 0   102702      1.000000
# 1    22625      0.979796
# 2   238889      0.846332

# %%
# You can reach the correlations between our user which has User-ID (153662) and other readers.
#       User-ID    Correlation
# 0     102702     1.000000
# 1      22625     0.979796
# 2     238889     0.846332

# In this case, our user has 153662 User-ID and you can reach similar readers with our user by using correlation each others.
# However this may not be good recommendation engine for the system since we did not calculate ratings. What i am trying to say,
# for example, a reader can be good correlate with our user, but it maybe voted low rating points. Therefore, we should take into account also ratings.
# Hence, we can recommend good rating books to readers.

# So, we should calculate Weighted Score.

similar_users_df = similar_users.merge(ratings, how='inner',on='User-ID')
similar_users_df = similar_users_df.merge(books,how='inner', on='ISBN')
similar_users_df = similar_users_df[similar_users_df['User-ID'] != user]

# Calculation Weighted Score
similar_users_df['Weighted Score'] = (0.4 * similar_users_df['Correlations'] + 0.6 * (similar_users_df['Book-Rating'] / 10)) / 2

# %%
similar_users_df.sort_values(by='Weighted Score',ascending=False)

similar_users_df.groupby('User-ID').agg({'Weighted Score':'mean'})
#         Weighted Score
# User-ID
# 22625          0.313127
# 102702         0.344213
# 238889         0.411321

# We can say that the 238889 User-ID has most recommended reader with our user on average.
# Out:
#          Weighted Score
# User-ID
# 22625          0.313127
# 102702         0.344213
# 238889         0.411321

# %%
# Finally, we can calculate the weighted score on books. Additionally, a threshold has to be determined for the score, in this case 8.5,
# so that the recommender system do not recommend to the users all of the books which have scores.
recommendation_df = similar_users_df.groupby('Book-Title').agg({'Weighted Score':'mean'}).reset_index()
recommendation_df_by_score = recommendation_df[recommendation_df["Weighted Score"] > 0.40].sort_values(by='Weighted Score',ascending=False)
recommendation_df_by_score = recommendation_df_by_score.merge(books, how='inner',on='Book-Title')
recommendation_df_by_score
# Out:
#                                             Book-Title  Weighted Score  \
# 0                                         Frisco's Kid        0.500000
# 1        The Dragon Queen (Tales of Guinevere, Book 1)        0.500000
# 2                                        Hot Chocolate        0.500000
# 3                                     The Defiant Hero        0.500000
# 4                                     The Defiant Hero        0.500000
# ..                                                 ...             ...
# 585                                             Saints        0.409266
# 586                                             Saints        0.409266
# 587               Kindred (Black Women Writers Series)        0.405959
# 588                         A Monk Swimming : A Memoir        0.405959
# 589  CHOCOLATE FOR A WOMAN'S SPIRIT : 77 STORIES OF...        0.405959
#
#            ISBN        Book-Author Year-Of-Publication     Publisher  \
# 0    1551667592  Suzanne Brockmann                2003          Mira
# 1    0345443993    ALICE BORCHARDT                2001       Del Rey
# 2    0515124524            Forster                1999    Jove Books
# 3    0345463404  SUZANNE BROCKMANN                2003     Ivy Books
# 4    0804119538  SUZANNE BROCKMANN                2001     Ivy Books
# ..          ...                ...                 ...           ...
# 585  0812581407   Orson Scott Card                1988     Tor Books
# 586  0312876068   Orson Scott Card                2001         Forge
# 587  0807083054     Octavia Butler                1988  Beacon Press
# 588  0786884142    Malachy McCourt                1999      Hyperion
# 589  068484897X     Kay Allenbaugh                1999      Fireside
#
#                                            Image-URL-S  \
# 0    http://images.amazon.com/images/P/1551667592.0...
# 1    http://images.amazon.com/images/P/0345443993.0...
# 2    http://images.amazon.com/images/P/0515124524.0...
# 3    http://images.amazon.com/images/P/0345463404.0...
# 4    http://images.amazon.com/images/P/0804119538.0...
# ..                                                 ...
# 585  http://images.amazon.com/images/P/0812581407.0...
# 586  http://images.amazon.com/images/P/0312876068.0...
# 587  http://images.amazon.com/images/P/0807083054.0...
# 588  http://images.amazon.com/images/P/0786884142.0...
# 589  http://images.amazon.com/images/P/068484897X.0...
#
#                                            Image-URL-M  \
# 0    http://images.amazon.com/images/P/1551667592.0...
# 1    http://images.amazon.com/images/P/0345443993.0...
# 2    http://images.amazon.com/images/P/0515124524.0...
# 3    http://images.amazon.com/images/P/0345463404.0...
# 4    http://images.amazon.com/images/P/0804119538.0...
# ..                                                 ...
# 585  http://images.amazon.com/images/P/0812581407.0...
# 586  http://images.amazon.com/images/P/0312876068.0...
# 587  http://images.amazon.com/images/P/0807083054.0...
# 588  http://images.amazon.com/images/P/0786884142.0...
# 589  http://images.amazon.com/images/P/068484897X.0...
#
#                                            Image-URL-L
# 0    http://images.amazon.com/images/P/1551667592.0...
# 1    http://images.amazon.com/images/P/0345443993.0...
# 2    http://images.amazon.com/images/P/0515124524.0...
# 3    http://images.amazon.com/images/P/0345463404.0...
# 4    http://images.amazon.com/images/P/0804119538.0...
# ..                                                 ...
# 585  http://images.amazon.com/images/P/0812581407.0...
# 586  http://images.amazon.com/images/P/0312876068.0...
# 587  http://images.amazon.com/images/P/0807083054.0...
# 588  http://images.amazon.com/images/P/0786884142.0...
# 589  http://images.amazon.com/images/P/068484897X.0...
#
# [590 rows x 9 columns]

# %%
# Lastly, we can determine a list to will be recommended.
recommended_list = recommendation_df_by_score.sort_values(by='Weighted Score',ascending=False).drop_duplicates(subset='Book-Title')['Book-Title'].head(10).to_list()
recommended_list
# Out:
# ["Frisco's Kid",
#  'Blue Heaven, Black Night (Zebra Regency Romance)',
#  'Caught In The Act',
#  'The Wilde Side',
#  'Unexpected',
#  'Wanton (Blaze) (Harlequin Temptation, No. 752)',
#  'American Heroes: Riley',
#  'Dark Gold',
#  'Conquer the Night',
#  'Dance With The Devil: A Dark-Hunter Novel']
